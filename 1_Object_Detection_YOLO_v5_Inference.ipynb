# %% [markdown]
# Install dependencies

# %%
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies
# Out:
#      |████████████████████████████████| 596 kB 33.5 MB/s

# %% [markdown]
# Import libraries

# %%
import torch

# %% [markdown]
# ## 2. Model
# Load pre-trained model.

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-6-22 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# ## 3. Inference

# %%
# Images for inference
imgs = ['/content/birds.png']  # batch of images

# %%
# Run inference
results2 = model(imgs2)

# %%
results2.print()
# Out:
# image 1/1: 1096x1936 3 birds
# Speed: 59.8ms pre-process, 20.7ms inference, 1.5ms NMS per image at shape (1, 3, 384, 640)

# %%
results2.save() #or show()
# Out:
# Saved 1 image to runs/detect/exp2

# %% [markdown]
# ## 4. Visualize

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/exp2/birds.jpg', width=800)

# %%
results2.pandas().xyxy[0]
# Out:
#           xmin        ymin         xmax        ymax  confidence  class  name
# 0   591.257019  282.143433   673.677673  367.749603    0.787382     14  bird
# 1   373.166412  384.807831   539.836304  511.517181    0.697824     14  bird
# 2  1124.814819  211.175430  1180.895508  289.349731    0.606813     14  bird
