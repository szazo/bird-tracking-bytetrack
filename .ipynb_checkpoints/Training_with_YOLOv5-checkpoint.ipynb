# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from IPython.display import Image, clear_output  # to display output 
clear_output()
print('setup complete .Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'cpu'))
# Out:
# setup complete .Using torch 1.11.0+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
! unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Inference
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.016s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.016s)
# Speed: 0.4ms pre-process, 16.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# Images for inference
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)


imgs = ['/content/022.png']  # batch of images
# # Run inference
results2 = model(imgs)
results2.print()
results2.save()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-6-23 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# Saved 1 image to runs/detect/exp7
# image 1/1: 1096x1936 2 birds, 1 cat
# Speed: 58.4ms pre-process, 14.1ms inference, 1.4ms NMS per image at shape (1, 3, 384, 640)

# %%
Image(filename='/content/yolov5/runs/detect/exp7/022.jpg', width=600) # to be change later

# %% [markdown]
# # 2. Validate

# %% [markdown]
# ## COCO val

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %% [markdown]
# # 3. Train

# %%
# Train YOLOv5s on custom_data for 3 epochs
# sometimes we need to decrize the batch size if gpu out of memmory 
# !python train.py --img 640 --batch 16 --epochs 3 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
print('show labels')
Image(filename='/content/yolov5/runs/train/exp2/val_batch0_labels.jpg', width=600) # to be change later
# Out:
# show labels

# %%
print('show predicted')
Image(filename='/content/yolov5/runs/train/exp2/val_batch0_pred.jpg', width=600) # to be change later
# Out:
# show predicted

# %% [markdown]
# # Training with 25 eps

# %%
# !python train.py --img 640 --batch 16 --epochs 25 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
print('show labels with 25 epos')
Image(filename='/content/yolov5/runs/train/exp3/val_batch0_labels.jpg', width=600) # to be change later
# Out:
# show labels with 25 epos

# %%
print('show predicted with 25 epos')
Image(filename='/content/yolov5/runs/train/exp3/val_batch0_pred.jpg', width=600) # to be change later
# Out:
# show predicted with 25 epos

# %% [markdown]
# # Training with 60 EPOS

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
print('show labels with 60 epos')
Image(filename='/content/yolov5/runs/train/exp4/val_batch0_labels.jpg', width=600) # to be change later
# Out:
# show labels with 60 epos

# %%
print('show predicted with 60 epos')
Image(filename='/content/yolov5/runs/train/exp4/val_batch0_pred.jpg', width=600) # to be change later
# Out:
# show predicted with 60 epos

# %% [markdown]
# # Infrance with video (our data set)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# !python detect.py --weights runs/train/exp4/weights/last.pt  --img 640 --conf 0.25 --source ../bird_video1.mp4
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=../bird_video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86173414 parameters, 0 gradients
# video 1/1 (1/922) /content/bird_video1.mp4: 384x640 3 birds, Done. (0.059s)
# video 1/1 (2/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.059s)
# video 1/1 (3/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.042s)
# video 1/1 (4/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.042s)
# ...

# %% [markdown]
# # Changing the confidance to bigger

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# !python detect.py --weights runs/train/exp4/weights/last.pt  --img 640 --conf 0.35 --source ../bird_video1.mp4
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=../bird_video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86173414 parameters, 0 gradients
# video 1/1 (1/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.064s)
# video 1/1 (2/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.064s)
# video 1/1 (3/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.040s)
# video 1/1 (4/922) /content/bird_video1.mp4: 384x640 2 birds, Done. (0.038s)
# ...
